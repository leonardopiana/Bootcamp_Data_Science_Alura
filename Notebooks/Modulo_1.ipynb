# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardopiana/Bootcamp_Data_Science_Alura/blob/main/Notebooks/Modulo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Módulo 1

# %% [markdown]
# ##Parte 1

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A160324189_28_143_208.csv", encoding = "ISO-8859-1", sep = ";",
                    skiprows=3, skipfooter=12, thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
#formatando a visualização do número da tabela (existem muitas variações de formatação)
pd.options.display.float_format = "{:.2f}".format

# %%
#visualização dos valores alterados
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago', kind = 'bar', figsize=(9,7))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind = 'bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalar Mensal por Unidade da Federação")
plt.show()

# %%
# Esse mês possui dados inválidos (caractere "-"), então aqui vamos substituir
# esses valores por um 0 e converter a coluna para float
dados["2020/Ago"] = dados["2020/Ago"].replace("-", 0).astype("float")

# %%
ax = dados.plot(x='Unidade da Federação', y='2020/Ago', kind = 'bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalar Mensal por Unidade da Federação")
plt.show()

# %% [markdown]
# ##Parte *2*

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# 2020/Ago     19144523.30
# Total      5993724452.01
# Length: 158, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Ago         Total
# 0          11 Rondônia   4209.37  ...  3556381.57  929129659.72
# 1              12 Acre  10470.07  ...        0.00  420668039.63
# 2          13 Amazonas  35752.72  ...  4726485.73 1771654871.23
# 3           14 Roraima   4785.91  ...  1524478.04  305010883.18
# 4              15 Pará 181159.29  ... 11559714.54 4437115730.71
#
# [5 rows x 159 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis.head(10)
# Out:
#                       2007/Ago   2007/Set  ...    2020/Ago         Total
# Unidade da Federação                       ...
# 11 Rondônia            4209.37   16397.03  ...  3556381.57  929129659.72
# 12 Acre               10470.07   14001.71  ...        0.00  420668039.63
# 13 Amazonas           35752.72   45570.64  ...  4726485.73 1771654871.23
# 14 Roraima             4785.91   11858.63  ...  1524478.04  305010883.18
# 15 Pará              181159.29  433414.74  ... 11559714.54 4437115730.71
# 16 Amapá              33672.74  104822.98  ...   834187.31  291637984.75
# 17 Tocantins           4113.76   76633.06  ...  2453362.74  999998621.85
# 21 Maranhão          385330.18 1018352.93  ... 10916718.78 3632860959.84
# 22 Piauí             220788.25  353468.67  ...  7926321.69 2130616492.35
# 23 Ceará             357904.65  572356.18  ... 14559529.59 6197357245.98
#
# [10 rows x 158 columns]

# %%
usaveis["2019/Ago"]
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374191.37
# 22 Piauí                  17816404.11
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073307.72
# 25 Paraíba                19854699.54
# 26 Pernambuco             71735626.96
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77852441.31
# 31 Minas Gerais          161707825.05
# 32 Espírito Santo         29298721.79
# 33 Rio de Janeiro         83311603.59
# 35 São Paulo             302367276.77
# 41 Paraná                127174095.05
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98546110.10
# 50 Mato Grosso do Sul     19217982.14
# ...

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# 2020/Ago           0.00
# Total      420668039.63
# Name: 12 Acre, Length: 158, dtype: float64

# %%
usaveis.T.plot(figsize=(9,6))

# %%
usaveis = usaveis.drop("Total", axis = 1)

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(9,6))

# %%
#mudando a legenda de lugar, existem vários outros jeitos de fazer isso
#URL de jeitos de mudar a legenda: "https://stackoverflow.com/questions/4700614/how-to-put-the-legend-out-of-the-plot"
ax = usaveis.T.plot( kind = 'line', figsize=(9,6))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalare Mensal por Unidade da Federação")
plt.show()

# %%
# O .plot retona um objeto que representa os eixos do gráfico
# aqui salvamos esse objeto em ax para futuras configurações
ax = usaveis.T.plot(figsize=(10,6))

# A partir do ax configuramos a posição da legenda com o legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4) 
# upper center posicionar no meio e o bbox_to_anchor ajustar posição e ncol = número de colunas

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linha
# - Eixo X: Anos/meses
# - Eixo Y: Valores
# - O que está sendo mostrado: Baseado ainda no gráfico anterior, foi reposicionada a legenda abaixo do gráfico em quatro colunas, pois encontrava-se no meio atrapalhando a visualização para todos os vinte e seis Estados Brasileiros mais o Distrito Federal.

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
cinco_estados = usaveis.loc[["11 Rondônia", "12 Acre", "13 Amazonas", "14 Roraima", "15 Pará" ]]
cinco_estados
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
#Minha tentativa de plotar 5 estados
ax = cinco_estados.T.plot( kind = 'line', figsize=(9,6))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalare Mensal por Unidade da Federação")
plt.show()

# %% [markdown]
# ##Parte 3

# %%
#Buscar informações sobre paletas de cores do Matplotlib - peguei da revisão no curso

# %% [markdown]
# [palheta acessivel](https://davidmathlogic.com/colorblind/#%23006BA4-%23FF800E-%23ABABAB-%23595959-%235F9ED1-%23C85200-%23898989-%23A2C8EC-%23FFBC79-%23CFCFCF-%231420f7-%2362ad3a-%232c82f4-%2324c7aa-%234eaabc-%233aacce-%23390c52-%23d83598-%2330d4f7-%23ad95c6-%23642c80-%23ee4961-%23603f43-%23966e83-%235b8d51-%231540f5-%233b7d54-%23ae0dde)

# %%
# Vamos alterar esse resultado de mudança de cores? Tô pensando em utilizar a pallete original {plt.style.use('tableau-colorblind10')} para cada região, assim garantimos uma visualização melhor
# do gráfico com a certeza da pallete respeitando as cores além de uma melhor visualização para análise. Bora? E podemos acrescentar tbm uma descrição do que está sendo visualizado.

# %% [markdown]
# Opção 1

# %%
# Criação manual do palete de cores
#color = ['#006BA4', '#FF800E', '#ABABAB', '#595959', '#5F9ED1', '#C85200', '#898989', '#A2C8EC', '#FFBC79', '#CFCFCF',
        #  '#AE0DDE', '#3B7D54', '#1540F5', '#5B8D51', '#966E83', '#603F43', '#EE4961', '#642C80', '#AD95C6', '#30D4F7',
        #  '#D83598', '#390C52', '#3AACCE', '#4EAABC', '#24C7AA', '#2C82F4', '#62AD3A']
#len(color) #o comando len traz o comprimento total

# %% [markdown]
# Opção 2

# %%
import numpy as np
from matplotlib import cm

color = cm.gist_rainbow(np.linspace(.0, 1, 27)) # Cria uma lista de cores baseada na paleta gist_rainbow do matplotlib usando numpy

#plt.style.use('tableau-colorblind10') #acessivel para 10 cores 
ax = usaveis.T.plot(figsize=(14,7), color=color)
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4)
#ax = usaveis.T.plot(figsize=(10,6), colormap='tab20b')

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linhas
# - Eixo X: Ano/mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Ainda utilizando o gráfico anterior, fizemos a alteração da paleta de cores baseada em uma paleta disponível na biblioteca matplotlib para pessoas com daltonismo para todos os 26 Estados Brasileiros mais o Distrito Federal.

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[0:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:7].T.plot(figsize=(9,6))

# %%
#outro jeito de buscar X estados dentro do do df para plotar
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2020/Jul    2020/Ago
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  27460475.47 10824255.26
# 31 Minas Gerais        971394.37 2861781.50  ... 120467187.34 57473699.06
# 24 Rio Grande do Norte 134605.36  272088.08  ...  19593057.45  8080160.97
# 17 Tocantins             4113.76   76633.06  ...   4489665.87  2453362.74
# 53 Distrito Federal    191951.47  769966.25  ...  22233542.26 12044848.02
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  12508717.35  4059220.22
# 16 Amapá                33672.74  104822.98  ...   2155083.37   834187.31
#
# [7 rows x 157 columns]

# %%
estados = usaveis.index
estados
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
#['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste']

# %%
regioes = [] #lista vazia

# %%
# Segunda opção de adicionar coluna com Regiões de cada Estado:
 
# Utilizamos o conhecimento da célula acima substituindo o nome do Estado, 
# pelo da sua Região referente e adicionamos a coluna ao DataSet.
usaveis["Regioes"] = ['Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Nordeste', 'Nordeste', 'Nordeste','Nordeste', 'Nordeste', 'Nordeste', 'Nordeste','Nordeste', 'Nordeste', 'Sudeste', 'Sudeste','Sudeste', 'Sudeste', 'Sul', 'Sul','Sul', 'Centro-Oeste', 'Centro-Oeste','Centro-Oeste', 'Centro-Oeste']
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Ago  Regioes
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  3556381.57    Norte
# 12 Acre               10470.07  14001.71  ...        0.00    Norte
# 13 Amazonas           35752.72  45570.64  ...  4726485.73    Norte
# 14 Roraima             4785.91  11858.63  ...  1524478.04    Norte
# 15 Pará              181159.29 433414.74  ... 11559714.54    Norte
#
# [5 rows x 158 columns]

# %% [markdown]
# opção 2

# %%
##mais sofisticada, não entendi muito bem o que é feito
# regions_map = {'1': 'Norte', '2': 'Nordeste', '3': 'Sudeste', '4': 'Sul', '5': 'Centro-Oeste'}

# def aplica_mapa(i):
#     return regions_map[i[0]]

# usaveis.index.map(aplica_mapa)
# usaveis.index.map(lambda i: regions_map[i[0]])

# %%
usaveis["Total"] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...  Regioes         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...    Norte  929129055.39
# 12 Acre               10470.07  14001.71  ...    Norte  420666755.81
# 13 Amazonas           35752.72  45570.64  ...    Norte 1771652039.82
# 14 Roraima             4785.91  11858.63  ...    Norte  305010469.49
# 15 Pará              181159.29 433414.74  ...    Norte 4437097195.11
#
# [5 rows x 159 columns]

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending = False)
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)
ordenado_por_total = ordenado_por_total.drop("Regioes", axis=1)
ordenado_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jul     2020/Ago
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 282709570.31 140414944.95
# 31 Minas Gerais       971394.37 2861781.50  ... 120467187.34  57473699.06
# 41 Paraná             554800.22 1431708.01  ...  80320852.69  41542401.16
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  78929703.81  28349257.38
# 33 Rio de Janeiro     469469.34  921646.57  ...  71540227.33  36264322.65
#
# [5 rows x 157 columns]

# %%
ordenado_por_total[:5].T.plot(figsize=(9,6))

# %%
ax = ordenado_por_total[:5].T.plot( kind = 'line', figsize=(9,6))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.title("Cinco Estados da Federação com mais Gastos Hospitalares Mensal", fontsize = 16)
ax.set_xticklabels( ax.get_xticklabels(), rotation=45, ha = "right") # rotacionando a legenda do Eixo X com a origem da rotação pela direita, get_xticklabels retorna os rótulos do eixo x
ax.set_ylabel("Valores em milhões de reais")
plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Podemos observar os cinco Estados com maiores gastos compreendidos entre agosto de 2007 e abril de 2019. Em ordem crescente temos: Rio de Janeiro, Rio Grande do Sul, Paraná, Minas Gerais e por último com o maior gasto o Estado de São Paulo.

# %%
top_5 = list(ordenado_por_total.head(5).index) #5 estados com maior custo total relacionado a internação pelo SUS
top_5_mais_DF = top_5 + ['53 Distrito Federal']
top_5_mais_DF
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '53 Distrito Federal']

# %%
ax = ordenado_por_total.T[top_5_mais_DF].plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %%
ax = ordenado_por_total.T[top_5_mais_DF].plot(figsize=(10,6))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

plt.title("Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019") 
plt.ylim(0, 350000000)

plt.show()

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total.head(5).T.plot(figsize = (9,6))

# %%
#plotar somente os estados do sudeste
ax = usaveis.query("Regioes == 'Sudeste'").drop(["Total", "Regioes"], axis=1).T.iloc[6:].plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019") 


plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Estamos visualizando a região Sudeste para comparar a sazonalidade entre os Estados São Paulo, Minas Gerais, Espírito Santo e Rio de Janeiro, seria visualizada em todos.

# %% [markdown]
# Análise do Gráfico
#
# Podemos observar que a sazonalidade não se repete nos outros estados da região sudeste, conforme observamos acontecer nos Estados de São Paulo, Rio de Janeiro e Minas Gerais.

# %% [markdown]
# ##Parte 4

# %%
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize = (9,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (9,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (9,6))
plt.ylim(0,350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# ##Parte 5

# %%
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2020/Ago'

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           140.41
# 31 Minas Gerais         57.47
# 41 Paraná               41.54
# 43 Rio Grande do Sul    28.35
# 33 Rio de Janeiro       36.26
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mais_recente.plot()

# %%
gastos_do_mais_recente.plot(kind='pie')

# %%
#visualização simples para valores absolutos

gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             140.41
# 31 Minas Gerais           57.47
# 41 Paraná                 41.54
# 43 Rio Grande do Sul      28.35
# 33 Rio de Janeiro         36.26
# 29 Bahia                  26.02
# 26 Pernambuco             33.54
# 42 Santa Catarina         16.99
# 23 Ceará                  14.56
# 52 Goiás                  20.24
# 15 Pará                   11.56
# 21 Maranhão               10.92
# 32 Espírito Santo         10.82
# 24 Rio Grande do Norte     8.08
# 25 Paraíba                 8.59
# 53 Distrito Federal       12.04
# 50 Mato Grosso do Sul      4.06
# 22 Piauí                   7.93
# 27 Alagoas                 6.49
# 51 Mato Grosso             6.17
# 13 Amazonas                4.73
# 28 Sergipe                 1.74
# 17 Tocantins               2.45
# 11 Rondônia                3.56
# 12 Acre                    0.00
# 14 Roraima                 1.52
# 16 Amapá                   0.83
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["35 São Paulo"]
# Out:
# Unidade da Federação
# 35 São Paulo             1.00
# 31 Minas Gerais          0.41
# 41 Paraná                0.30
# 43 Rio Grande do Sul     0.20
# 33 Rio de Janeiro        0.26
# 29 Bahia                 0.19
# 26 Pernambuco            0.24
# 42 Santa Catarina        0.12
# 23 Ceará                 0.10
# 52 Goiás                 0.14
# 15 Pará                  0.08
# 21 Maranhão              0.08
# 32 Espírito Santo        0.08
# 24 Rio Grande do Norte   0.06
# 25 Paraíba               0.06
# 53 Distrito Federal      0.09
# 50 Mato Grosso do Sul    0.03
# 22 Piauí                 0.06
# 27 Alagoas               0.05
# 51 Mato Grosso           0.04
# 13 Amazonas              0.03
# 28 Sergipe               0.01
# 17 Tocantins             0.02
# 11 Rondônia              0.03
# 12 Acre                  0.00
# 14 Roraima               0.01
# 16 Amapá                 0.01
# Name: 2020/Ago, dtype: float64

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["35 São Paulo"]).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           1.00
# 31 Minas Gerais        0.41
# 41 Paraná              0.30
# 43 Rio Grande do Sul   0.20
# 33 Rio de Janeiro      0.26
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending = False)
gastos_do_mais_recente.plot(kind = 'bar')

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["35 São Paulo"]).plot(kind = 'bar')

# %% [markdown]
# Estado escolhido: São Paulo (meu estado de origem)
#
# Analisando esse gráfico, podemos ver que os gastos de São Paulo são os maiores, nenhum estado chega nem na metade dos gastos de SP. Muito provavelmente isso de deve a população do estado de São Paulo, e os estados que vem logo em seguida devem ser os que possuem as maiores populações depois de SP.

# %%
#desafio: colocar grid no gráfico
#documentação: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html#pandas-dataframe-plot

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar', grid=True)

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável gastos_do_mais_recente
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Valores
# - O que está sendo mostrado: Foi adicionado ao gráfico o recurso grid, ou grades, que facilitam a medição dos valores mostrados.

# %%
#desafio: gráfico de barras do gasto dos outros estados em função ao seu estado
gastos_recente_em_funcao_ao_df = (gastos_do_mais_recente / gastos_do_mais_recente.loc['53 Distrito Federal'])
ax = gastos_recente_em_funcao_ao_df.sort_values(ascending=False).plot(kind='bar', grid=True, figsize=(15,5))
ax.set_title("Gastos dos estados referente a internações no SUS de Julho de 2020 em função aos gastos do Distrito Federal")
plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Gastos dos estados referente a internações no SUS de Julho de 2020 em função aos gastos do Distrito Federal
# - Base de dados utilizada: Variável gastos_recente_em_funcao_ao_df
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Valores em função do Distrito Federal
# - O que está sendo mostrado: Neste gráfico é mostrado a proporção de diferença entre os gastos dos Estados em função do Distrito Federal. São Paulo possuí 13 vezes o valor de gastos do Distrito Federal.

# %%
#desafio: gastos por população de dois estados.
#origem dos dados: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
dict_estado_populacao = {'35 São Paulo':	46289333,	
'31 Minas Gerais':	21331292,
'33 Rio de Janeiro':	17366189,
'29 Bahia':	14930634,
'41 Paraná':	11516840,
'43 Rio Grande do Sul':	11422973,
'26 Pernambuco':	9616621,
'23 Ceará':	9187103,
'15 Pará':	8690745,
'42 Santa Catarina':	7279638,
'52 Goiás':	7142070,
'21 Maranhão':	7127460,
'13 Amazonas':	4228381,
'32 Espírito Santo':	4064052,
'25 Paraíba':	4039277,
'24 Rio Grande do Norte':	3534165,
'51 Mato Grosso':	3526220,
'27 Alagoas':	3351543,
'22 Piauí':	3281480,
'53 Distrito Federal':	3055149,
'50 Mato Grosso do Sul':	2809394,
'28 Sergipe':	2318822,
'11 Rondônia':	1796460,
'17 Tocantins':	1590248,
'12 Acre':	894470,
'16 Amapá':	861773,
'14 Roraima':	631181}

# %%
gasto_por_hab_por_estado = [[usaveis["Total"].loc[estado] / dict_estado_populacao[estado], dict_estado_populacao[estado]] for estado in dict_estado_populacao.keys()]

# %%
df_gasto_por_hab
# Out:
#                         Gasto por habitante  Num de Habitantes
# 35 São Paulo                         840.79           46289333
# 31 Minas Gerais                      898.19           21331292
# 33 Rio de Janeiro                    558.34           17366189
# 29 Bahia                             615.76           14930634
# 41 Paraná                           1197.10           11516840
# 43 Rio Grande do Sul                1046.88           11422973
# 26 Pernambuco                        836.75            9616621
# 23 Ceará                             674.57            9187103
# 15 Pará                              510.55            8690745
# 42 Santa Catarina                   1006.09            7279638
# 52 Goiás                             652.09            7142070
# 21 Maranhão                          509.69            7127460
# 13 Amazonas                          418.99            4228381
# 32 Espírito Santo                    772.43            4064052
# ...

# %%
gasto_por_hab_por_estado = [[usaveis["Total"].loc[estado] / dict_estado_populacao[estado], dict_estado_populacao[estado]] for estado in dict_estado_populacao.keys()]
df_gasto_por_hab = pd.DataFrame(data=gasto_por_hab_por_estado, index=dict_estado_populacao.keys(), columns=['Gasto por habitante', 'Num de Habitantes'])
df_gasto_por_hab.sort_values(by='Num de Habitantes', ascending=False)['Gasto por habitante'].plot(kind='bar', grid=True, figsize=(15,5))
plt.title("Gastos por habitantes dos estados referente a internações no SUS de 2008 a 2020 ordenado por população")
plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Gastos por habitantes dos estados referente a internações no SUS de 2008 a 2020 ordenado por população
# - Base de dados utilizada: Variável df_gasto_por_hab
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Gasto por habitante
# - O que está sendo mostrado: Neste gráfico é mostrado o gasto por habitante referente a cada Estado no período entre 2008 e 2020.

# %%
def custo_hab(populacao_A, estado_A, populacao_B, estado_B): # Função para fazer cálculo por habitante comparando entre dois estados.
  gasto_A = usaveis["Total"].loc[estado_A] / populacao_A
  gasto_B = usaveis["Total"].loc[estado_B] / populacao_B
  df_gasto_por_hab = pd.DataFrame(data=[gasto_A, gasto_B], index=[estado_A, estado_B], columns=['Gasto por habitante'])
  df_gasto_por_hab.plot(kind='bar', grid=True, figsize=(15,5))

# %%
custo_hab(46289333, '35 São Paulo', 631181, '14 Roraima')

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável df_gasto_por_hab
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Gasto por habitante
# - O que está sendo mostrado: Neste gráfico é mostrado um comparativo direto entre os Estados de São Paulo e Roraima. Em São Paulo podemos observar os gastos em torno de 800 reais e em Roraima em torno de 500 reais.
