# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardopiana/Bootcamp_Data_Science_Alura/blob/main/Notebooks/Modulo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Módulo 1

# %% [markdown]
# ##Parte 1

# %%
URL = 'https://raw.githubusercontent.com/leonardopiana/Bootcamp_Data_Science_Alura/main/Dados/A160324189_28_143_208.csv'

# %%
import pandas as pd

# %%
dados = pd.read_csv(URL, encoding = "ISO-8859-1", sep = ";",
                    skiprows=3, skipfooter=12, thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
#formatando a visualização do número da tabela (existem muitas variações de formatação)
pd.options.display.float_format = "{:.2f}".format

# %%
#visualização dos valores alterados
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago', kind = 'bar', figsize=(9,7))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind = 'bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalar Mensal por Unidade da Federação")
plt.show()

# %%
# Esse mês possui dados inválidos (caractere "-"), então aqui vamos substituir
# esses valores por um 0 e converter a coluna para float
dados["2020/Ago"] = dados["2020/Ago"].replace("-", 0).astype("float")

# %%
ax = dados.plot(x='Unidade da Federação', y='2020/Ago', kind = 'bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalar Mensal por Unidade da Federação")
plt.show()

# %% [markdown]
# ##Parte *2*

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# 2020/Ago     19144523.30
# Total      5993724452.01
# Length: 158, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Ago         Total
# 0          11 Rondônia   4209.37  ...  3556381.57  929129659.72
# 1              12 Acre  10470.07  ...        0.00  420668039.63
# 2          13 Amazonas  35752.72  ...  4726485.73 1771654871.23
# 3           14 Roraima   4785.91  ...  1524478.04  305010883.18
# 4              15 Pará 181159.29  ... 11559714.54 4437115730.71
#
# [5 rows x 159 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis.head(10)
# Out:
#                       2007/Ago   2007/Set  ...    2020/Ago         Total
# Unidade da Federação                       ...
# 11 Rondônia            4209.37   16397.03  ...  3556381.57  929129659.72
# 12 Acre               10470.07   14001.71  ...        0.00  420668039.63
# 13 Amazonas           35752.72   45570.64  ...  4726485.73 1771654871.23
# 14 Roraima             4785.91   11858.63  ...  1524478.04  305010883.18
# 15 Pará              181159.29  433414.74  ... 11559714.54 4437115730.71
# 16 Amapá              33672.74  104822.98  ...   834187.31  291637984.75
# 17 Tocantins           4113.76   76633.06  ...  2453362.74  999998621.85
# 21 Maranhão          385330.18 1018352.93  ... 10916718.78 3632860959.84
# 22 Piauí             220788.25  353468.67  ...  7926321.69 2130616492.35
# 23 Ceará             357904.65  572356.18  ... 14559529.59 6197357245.98
#
# [10 rows x 158 columns]

# %%
usaveis["2019/Ago"]
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374191.37
# 22 Piauí                  17816404.11
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073307.72
# 25 Paraíba                19854699.54
# 26 Pernambuco             71735626.96
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77852441.31
# 31 Minas Gerais          161707825.05
# 32 Espírito Santo         29298721.79
# 33 Rio de Janeiro         83311603.59
# 35 São Paulo             302367276.77
# 41 Paraná                127174095.05
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98546110.10
# 50 Mato Grosso do Sul     19217982.14
# ...

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# 2020/Ago           0.00
# Total      420668039.63
# Name: 12 Acre, Length: 158, dtype: float64

# %%
usaveis.T.plot(figsize=(9,6))

# %%
usaveis = usaveis.drop("Total", axis = 1)

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(9,6))

# %%
#mudando a legenda de lugar, existem vários outros jeitos de fazer isso
#URL de jeitos de mudar a legenda: "https://stackoverflow.com/questions/4700614/how-to-put-the-legend-out-of-the-plot"
ax = usaveis.T.plot( kind = 'line', figsize=(9,6))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalare Mensal por Unidade da Federação")
plt.show()

# %%
# O .plot retona um objeto que representa os eixos do gráfico
# aqui salvamos esse objeto em ax para futuras configurações
ax = usaveis.T.plot(figsize=(10,6))

# A partir do ax configuramos a posição da legenda com o legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4) 
# upper center posicionar no meio e o bbox_to_anchor ajustar posição e ncol = número de colunas

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linha
# - Eixo X: Anos/meses
# - Eixo Y: Valores
# - O que está sendo mostrado: Baseado ainda no gráfico anterior, foi reposicionada a legenda abaixo do gráfico em quatro colunas, pois encontrava-se no meio atrapalhando a visualização para todos os vinte e seis Estados Brasileiros mais o Distrito Federal.

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
cinco_estados = usaveis.loc[["11 Rondônia", "12 Acre", "13 Amazonas", "14 Roraima", "15 Pará" ]]
cinco_estados
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul    2020/Ago
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  3556381.57
# 12 Acre               10470.07  14001.71  ...  1163813.08        0.00
# 13 Amazonas           35752.72  45570.64  ... 13358514.02  4726485.73
# 14 Roraima             4785.91  11858.63  ...  2739498.41  1524478.04
# 15 Pará              181159.29 433414.74  ... 27618727.51 11559714.54
#
# [5 rows x 157 columns]

# %%
#Minha tentativa de plotar 5 estados
ax = cinco_estados.T.plot( kind = 'line', figsize=(9,6))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Gasto Hospitalare Mensal por Unidade da Federação")
plt.show()

# %% [markdown]
# ##Parte 3

# %%
#Buscar informações sobre paletas de cores do Matplotlib - peguei da revisão no curso

# %% [markdown]
# [palheta acessivel](https://davidmathlogic.com/colorblind/#%23006BA4-%23FF800E-%23ABABAB-%23595959-%235F9ED1-%23C85200-%23898989-%23A2C8EC-%23FFBC79-%23CFCFCF-%231420f7-%2362ad3a-%232c82f4-%2324c7aa-%234eaabc-%233aacce-%23390c52-%23d83598-%2330d4f7-%23ad95c6-%23642c80-%23ee4961-%23603f43-%23966e83-%235b8d51-%231540f5-%233b7d54-%23ae0dde)

# %%
# Vamos alterar esse resultado de mudança de cores? Tô pensando em utilizar a pallete original {plt.style.use('tableau-colorblind10')} para cada região, assim garantimos uma visualização melhor
# do gráfico com a certeza da pallete respeitando as cores além de uma melhor visualização para análise. Bora? E podemos acrescentar tbm uma descrição do que está sendo visualizado.

# %% [markdown]
# Opção 1

# %%
# Criação manual do palete de cores
#color = ['#006BA4', '#FF800E', '#ABABAB', '#595959', '#5F9ED1', '#C85200', '#898989', '#A2C8EC', '#FFBC79', '#CFCFCF',
        #  '#AE0DDE', '#3B7D54', '#1540F5', '#5B8D51', '#966E83', '#603F43', '#EE4961', '#642C80', '#AD95C6', '#30D4F7',
        #  '#D83598', '#390C52', '#3AACCE', '#4EAABC', '#24C7AA', '#2C82F4', '#62AD3A']
#len(color) #o comando len traz o comprimento total

# %% [markdown]
# Opção 2

# %%
import numpy as np
from matplotlib import cm

color = cm.gist_rainbow(np.linspace(.0, 1, 27)) # Cria uma lista de cores baseada na paleta gist_rainbow do matplotlib usando numpy

#plt.style.use('tableau-colorblind10') #acessivel para 10 cores 
ax = usaveis.T.plot(figsize=(14,7), color=color)
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4)
#ax = usaveis.T.plot(figsize=(10,6), colormap='tab20b')

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linhas
# - Eixo X: Ano/mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Ainda utilizando o gráfico anterior, fizemos a alteração da paleta de cores baseada em uma paleta disponível na biblioteca matplotlib para pessoas com daltonismo para todos os 26 Estados Brasileiros mais o Distrito Federal.

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[0:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:7].T.plot(figsize=(9,6))

# %%
#outro jeito de buscar X estados dentro do do df para plotar
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2020/Jul    2020/Ago
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  27460475.47 10824255.26
# 31 Minas Gerais        971394.37 2861781.50  ... 120467187.34 57473699.06
# 24 Rio Grande do Norte 134605.36  272088.08  ...  19593057.45  8080160.97
# 17 Tocantins             4113.76   76633.06  ...   4489665.87  2453362.74
# 53 Distrito Federal    191951.47  769966.25  ...  22233542.26 12044848.02
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  12508717.35  4059220.22
# 16 Amapá                33672.74  104822.98  ...   2155083.37   834187.31
#
# [7 rows x 157 columns]

# %%
estados = usaveis.index
estados
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
#['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste']

# %%
regioes = [] #lista vazia

# %%
# Segunda opção de adicionar coluna com Regiões de cada Estado:
 
# Utilizamos o conhecimento da célula acima substituindo o nome do Estado, 
# pelo da sua Região referente e adicionamos a coluna ao DataSet.
usaveis["Regioes"] = ['Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Nordeste', 'Nordeste', 'Nordeste','Nordeste', 'Nordeste', 'Nordeste', 'Nordeste','Nordeste', 'Nordeste', 'Sudeste', 'Sudeste','Sudeste', 'Sudeste', 'Sul', 'Sul','Sul', 'Centro-Oeste', 'Centro-Oeste','Centro-Oeste', 'Centro-Oeste']
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Ago  Regioes
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  3556381.57    Norte
# 12 Acre               10470.07  14001.71  ...        0.00    Norte
# 13 Amazonas           35752.72  45570.64  ...  4726485.73    Norte
# 14 Roraima             4785.91  11858.63  ...  1524478.04    Norte
# 15 Pará              181159.29 433414.74  ... 11559714.54    Norte
#
# [5 rows x 158 columns]

# %% [markdown]
# opção 2

# %%
##mais sofisticada, não entendi muito bem o que é feito
# regions_map = {'1': 'Norte', '2': 'Nordeste', '3': 'Sudeste', '4': 'Sul', '5': 'Centro-Oeste'}

# def aplica_mapa(i):
#     return regions_map[i[0]]

# usaveis.index.map(aplica_mapa)
# usaveis.index.map(lambda i: regions_map[i[0]])

# %%
usaveis["Total"] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...  Regioes         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...    Norte  929129055.39
# 12 Acre               10470.07  14001.71  ...    Norte  420666755.81
# 13 Amazonas           35752.72  45570.64  ...    Norte 1771652039.82
# 14 Roraima             4785.91  11858.63  ...    Norte  305010469.49
# 15 Pará              181159.29 433414.74  ...    Norte 4437097195.11
#
# [5 rows x 159 columns]

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending = False)
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)
ordenado_por_total = ordenado_por_total.drop("Regioes", axis=1)
ordenado_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jul     2020/Ago
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 282709570.31 140414944.95
# 31 Minas Gerais       971394.37 2861781.50  ... 120467187.34  57473699.06
# 41 Paraná             554800.22 1431708.01  ...  80320852.69  41542401.16
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  78929703.81  28349257.38
# 33 Rio de Janeiro     469469.34  921646.57  ...  71540227.33  36264322.65
#
# [5 rows x 157 columns]

# %%
ordenado_por_total[:5].T.plot(figsize=(9,6))

# %%
ax = ordenado_por_total[:5].T.plot( kind = 'line', figsize=(9,6))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.title("Cinco Estados da Federação com mais Gastos Hospitalares Mensal", fontsize = 16)
ax.set_xticklabels( ax.get_xticklabels(), rotation=45, ha = "right") # rotacionando a legenda do Eixo X com a origem da rotação pela direita, get_xticklabels retorna os rótulos do eixo x
ax.set_ylabel("Valores em milhões de reais")
plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Podemos observar os cinco Estados com maiores gastos compreendidos entre agosto de 2007 e abril de 2019. Em ordem crescente temos: Rio de Janeiro, Rio Grande do Sul, Paraná, Minas Gerais e por último com o maior gasto o Estado de São Paulo.

# %%
top_5 = list(ordenado_por_total.head(5).index) #5 estados com maior custo total relacionado a internação pelo SUS
top_5_mais_DF = top_5 + ['53 Distrito Federal']
top_5_mais_DF
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '53 Distrito Federal']

# %%
ax = ordenado_por_total.T[top_5_mais_DF].plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %%
ax = ordenado_por_total.T[top_5_mais_DF].plot(figsize=(10,6))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

plt.title("Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019") 
plt.ylim(0, 350000000)

plt.show()

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total.head(5).T.plot(figsize = (9,6))

# %%
#plotar somente os estados do sudeste
ax = usaveis.query("Regioes == 'Sudeste'").drop(["Total", "Regioes"], axis=1).T.iloc[6:].plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019") 


plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Estamos visualizando a região Sudeste para comparar a sazonalidade entre os Estados São Paulo, Minas Gerais, Espírito Santo e Rio de Janeiro, seria visualizada em todos.

# %% [markdown]
# Análise do Gráfico
#
# Podemos observar que a sazonalidade não se repete nos outros estados da região sudeste, conforme observamos acontecer nos Estados de São Paulo, Rio de Janeiro e Minas Gerais.

# %% [markdown]
# ##Parte 4

# %%
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize = (9,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (9,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (9,6))
plt.ylim(0,350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# ##Parte 5

# %%
mes_mais_recente = ordenado_por_total.columns[-2]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           282.71
# 31 Minas Gerais        120.47
# 41 Paraná               80.32
# 43 Rio Grande do Sul    78.93
# 33 Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente.plot()

# %%
gastos_do_mais_recente.plot(kind='pie')

# %%
#visualização simples para valores absolutos

gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             282.71
# 31 Minas Gerais          120.47
# 41 Paraná                 80.32
# 43 Rio Grande do Sul      78.93
# 33 Rio de Janeiro         71.54
# 29 Bahia                  58.90
# 26 Pernambuco             62.33
# 42 Santa Catarina         51.76
# 23 Ceará                  30.81
# 52 Goiás                  33.50
# 15 Pará                   27.62
# 21 Maranhão               24.37
# 32 Espírito Santo         27.46
# 24 Rio Grande do Norte    19.59
# 25 Paraíba                15.49
# 53 Distrito Federal       22.23
# 50 Mato Grosso do Sul     12.51
# 22 Piauí                  18.02
# 27 Alagoas                13.09
# 51 Mato Grosso            13.08
# 13 Amazonas               13.36
# 28 Sergipe                 3.31
# 17 Tocantins               4.49
# 11 Rondônia                7.41
# 12 Acre                    1.16
# 14 Roraima                 2.74
# 16 Amapá                   2.16
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["35 São Paulo"]
# Out:
# Unidade da Federação
# 35 São Paulo             1.00
# 31 Minas Gerais          0.43
# 41 Paraná                0.28
# 43 Rio Grande do Sul     0.28
# 33 Rio de Janeiro        0.25
# 29 Bahia                 0.21
# 26 Pernambuco            0.22
# 42 Santa Catarina        0.18
# 23 Ceará                 0.11
# 52 Goiás                 0.12
# 15 Pará                  0.10
# 21 Maranhão              0.09
# 32 Espírito Santo        0.10
# 24 Rio Grande do Norte   0.07
# 25 Paraíba               0.05
# 53 Distrito Federal      0.08
# 50 Mato Grosso do Sul    0.04
# 22 Piauí                 0.06
# 27 Alagoas               0.05
# 51 Mato Grosso           0.05
# 13 Amazonas              0.05
# 28 Sergipe               0.01
# 17 Tocantins             0.02
# 11 Rondônia              0.03
# 12 Acre                  0.00
# 14 Roraima               0.01
# 16 Amapá                 0.01
# Name: 2020/Jul, dtype: float64

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["35 São Paulo"]).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           1.00
# 31 Minas Gerais        0.43
# 41 Paraná              0.28
# 43 Rio Grande do Sul   0.28
# 33 Rio de Janeiro      0.25
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending = False)
gastos_do_mais_recente.plot(kind = 'bar')

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["35 São Paulo"]).plot(kind = 'bar')

# %% [markdown]
# Estado escolhido: São Paulo (meu estado de origem)
#
# Analisando esse gráfico, podemos ver que os gastos de São Paulo são os maiores, nenhum estado chega nem na metade dos gastos de SP. Muito provavelmente isso de deve a população do estado de São Paulo, e os estados que vem logo em seguida devem ser os que possuem as maiores populações depois de SP.

# %%
#desafio: colocar grid no gráfico
#documentação: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html#pandas-dataframe-plot

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar', grid=True)

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável gastos_do_mais_recente
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Valores
# - O que está sendo mostrado: Foi adicionado ao gráfico o recurso grid, ou grades, que facilitam a medição dos valores mostrados.

# %%
#desafio: gráfico de barras do gasto dos outros estados em função ao seu estado
gastos_recente_em_funcao_ao_df = (gastos_do_mais_recente / gastos_do_mais_recente.loc['53 Distrito Federal'])
ax = gastos_recente_em_funcao_ao_df.sort_values(ascending=False).plot(kind='bar', grid=True, figsize=(15,5))
ax.set_title("Gastos dos estados referente a internações no SUS de Julho de 2020 em função aos gastos do Distrito Federal")
plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Gastos dos estados referente a internações no SUS de Julho de 2020 em função aos gastos do Distrito Federal
# - Base de dados utilizada: Variável gastos_recente_em_funcao_ao_df
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Valores em função do Distrito Federal
# - O que está sendo mostrado: Neste gráfico é mostrado a proporção de diferença entre os gastos dos Estados em função do Distrito Federal. São Paulo possuí 13 vezes o valor de gastos do Distrito Federal.

# %%
#desafio: gastos por população de dois estados.
#origem dos dados: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
dict_estado_populacao = {'35 São Paulo':	46289333,	
'31 Minas Gerais':	21331292,
'33 Rio de Janeiro':	17366189,
'29 Bahia':	14930634,
'41 Paraná':	11516840,
'43 Rio Grande do Sul':	11422973,
'26 Pernambuco':	9616621,
'23 Ceará':	9187103,
'15 Pará':	8690745,
'42 Santa Catarina':	7279638,
'52 Goiás':	7142070,
'21 Maranhão':	7127460,
'13 Amazonas':	4228381,
'32 Espírito Santo':	4064052,
'25 Paraíba':	4039277,
'24 Rio Grande do Norte':	3534165,
'51 Mato Grosso':	3526220,
'27 Alagoas':	3351543,
'22 Piauí':	3281480,
'53 Distrito Federal':	3055149,
'50 Mato Grosso do Sul':	2809394,
'28 Sergipe':	2318822,
'11 Rondônia':	1796460,
'17 Tocantins':	1590248,
'12 Acre':	894470,
'16 Amapá':	861773,
'14 Roraima':	631181}

# %%
gasto_por_hab_por_estado = [[usaveis["Total"].loc[estado] / dict_estado_populacao[estado], dict_estado_populacao[estado]] for estado in dict_estado_populacao.keys()]

# %%
gasto_por_hab_por_estado = [[usaveis["Total"].loc[estado] / dict_estado_populacao[estado], dict_estado_populacao[estado]] for estado in dict_estado_populacao.keys()]
df_gasto_por_hab = pd.DataFrame(data=gasto_por_hab_por_estado, index=dict_estado_populacao.keys(), columns=['Gasto por habitante', 'Num de Habitantes'])
df_gasto_por_hab.sort_values(by='Num de Habitantes', ascending=False)['Gasto por habitante'].plot(kind='bar', grid=True, figsize=(15,5))
plt.title("Gastos por habitantes dos estados referente a internações no SUS de 2008 a 2020 ordenado por população")
plt.show()

# %% [markdown]
# Descrição gráfico
# - Título: Gastos por habitantes dos estados referente a internações no SUS de 2008 a 2020 ordenado por população
# - Base de dados utilizada: Variável df_gasto_por_hab
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Gasto por habitante
# - O que está sendo mostrado: Neste gráfico é mostrado o gasto por habitante referente a cada Estado no período entre 2008 e 2020.

# %%
def custo_hab(populacao_A, estado_A, populacao_B, estado_B): # Função para fazer cálculo por habitante comparando entre dois estados.
  gasto_A = usaveis["Total"].loc[estado_A] / populacao_A
  gasto_B = usaveis["Total"].loc[estado_B] / populacao_B
  df_gasto_por_hab = pd.DataFrame(data=[gasto_A, gasto_B], index=[estado_A, estado_B], columns=['Gasto por habitante'])
  df_gasto_por_hab.plot(kind='bar', grid=True, figsize=(15,5))

# %%
custo_hab(46289333, '35 São Paulo', 631181, '14 Roraima')

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável df_gasto_por_hab
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Gasto por habitante
# - O que está sendo mostrado: Neste gráfico é mostrado um comparativo direto entre os Estados de São Paulo e Roraima. Em São Paulo podemos observar os gastos em torno de 800 reais e em Roraima em torno de 500 reais.

# %% [markdown]
# #Módulo 2

# %% [markdown]
# ##Aula 1

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending = False)
gastos_do_mais_recente.plot(kind = 'bar')

# %%
gastos_proporcionais = gastos_do_mais_recente / gastos_do_mais_recente.sum()
gastos_proporcionais.plot(kind = 'bar')

# %%
ibge_estimativa = pd.read_excel("https://github.com/alura-cursos/agendamento-hospitalar/raw/main/dados/estimativa_dou_2020.xls")
ibge_estimativa.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  ...          Unnamed: 2
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO                                                                  ...  POPULAÇÃO ESTIMADA
# 1                                             Brasil                                                                  ...           211755692
# 2                                       Região Norte                                                                  ...            18672591
# 3                                           Rondônia                                                                  ...             1796460
# 4                                               Acre                                                                  ...              894470
#
# [5 rows x 3 columns]

# %%
dados_da_populacao = """Posição 	Unidade federativa 	População 	% da pop. total 	País comparável

(habitantes)
1 	 São Paulo 	46 649 132 	21,9% 	Flag of Spain.svg Espanha (46 439 864)
2 	 Minas Gerais 	21 411 923 	10,1% 	Sri Lanka (20 675 000)
3 	 Rio de Janeiro 	17 463 349 	8,2% 	 Países Baixos (16 922 900)
4 	Bahia Bahia 	14 985 284 	7,1% 	Chade (14 037 000)
5 	 Paraná 	11 597 484 	5,4% 	 Bolívia (11 410 651)
6 	 Rio Grande do Sul 	11 466 630 	5,4% 	 Bélgica (11 250 659)
7 	 Pernambuco 	9 674 793 	4,5% 	 Bielorrússia (9 485 300)
8 	 Ceará 	9 240 580 	4,3% 	 Emirados Árabes Unidos (9 157 000)
9 	Pará Pará 	8 777 124 	4,1% 	 Áustria (8 602 112)
10 	 Santa Catarina 	7 338 473 	3,4% 	 Sérvia (7 114 393)
11 	 Goiás 	7 206 589 	3,4% 	 Paraguai (7 003 406)
12 	 Maranhão 	7 153 262 	3,4% 	 Paraguai (7 003 406)
13 	 Amazonas 	4 269 995 	2,0% 	Líbano (4 168 000)
14 	 Espírito Santo 	4 108 508 	1,9% 	Líbano (4 168 000)
15 	 Paraíba 	4 059 905 	1,9% 	Líbano (4 168 000)
16 	 Mato Grosso 	3 567 234 	1,7% 	Uruguai (3 415 866)
17 	 Rio Grande do Norte 	3 560 903 	1,7% 	Uruguai (3 415 866)
18 	 Alagoas 	3 365 351 	1,6% 	Uruguai (3 415 866)
19 	 Piauí 	3 289 290 	1,6% 	Kuwait (3 268 431)
20 	 Distrito Federal 	3 094 325 	1,4% 	 Lituânia (2 900 787)
21 	 Mato Grosso do Sul 	2 839 188 	1,3% 	 Jamaica (2 717 991)
22 	 Sergipe 	2 338 474 	1,1% 	Namíbia (2 280 700)
23 	 Rondônia 	1 815 278 	0,8% 	Gabão (1 725 000)
24 	 Tocantins 	1 607 363 	0,7% 	 Bahrein (1 359 800)
25 	 Acre 	906 876 	0,4% 	Fiji (859 178)
26 	 Amapá 	877 613 	0,4% 	Fiji (859 178)
27 	 Roraima 	652 713 	0,3% 	 Luxemburgo (562 958)
"""

#fonte: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
from io import StringIO  #leitura de string, para conseguir pegar a informação de dentro da string acima (tabela copiada)

dados_da_populacao_io = StringIO(dados_da_populacao)

pd.read_csv(dados_da_populacao_io, sep="\t")
# Out:
#         Posição   ...                         País comparável
# 0   (habitantes)  ...                                     NaN
# 1             1   ...  Flag of Spain.svg Espanha (46 439 864)
# 2             2   ...                  Sri Lanka (20 675 000)
# 3             3   ...              Países Baixos (16 922 900)
# 4             4   ...                      Chade (14 037 000)
# 5             5   ...                    Bolívia (11 410 651)
# 6             6   ...                    Bélgica (11 250 659)
# 7             7   ...                Bielorrússia (9 485 300)
# 8             8   ...      Emirados Árabes Unidos (9 157 000)
# 9             9   ...                     Áustria (8 602 112)
# 10           10   ...                      Sérvia (7 114 393)
# 11           11   ...                    Paraguai (7 003 406)
# 12           12   ...                    Paraguai (7 003 406)
# 13           13   ...                      Líbano (4 168 000)
# ...

# %%
#limpar os dados, tirar as colunas não necessárias, retirar os espaços e transformar a uf em index
dados_da_populacao_io = StringIO(dados_da_populacao)
populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
populacao = populacao.dropna()
populacao["populacao"] = populacao["População "].str.replace(" ", "").astype(int)
populacao["uf"] = populacao["Unidade federativa "]
populacao = populacao[["populacao", "uf"]].set_index("uf")
display(populacao.head())
display(populacao.info())
# Out:
#                   populacao
# uf
#  São Paulo         46649132
#  Minas Gerais      21411923
#  Rio de Janeiro    17463349
# Bahia Bahia        14985284
#  Paraná            11597484
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries,  São Paulo  to  Roraima
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   populacao  27 non-null     int64
# dtypes: int64(1)
# memory usage: 432.0+ bytes
# None

# %%
populacao.index.str[:3]
# Out:
# Index([' Sã', ' Mi', ' Ri', 'Bah', ' Pa', ' Ri', ' Pe', ' Ce', 'Par', ' Sa',
#        ' Go', ' Ma', ' Am', ' Es', ' Pa', ' Ma', ' Ri', ' Al', ' Pi', ' Di',
#        ' Ma', ' Se', ' Ro', ' To', ' Ac', ' Am', ' Ro'],
#       dtype='object', name='uf')

# %%
gastos_do_mais_recente.index = gastos_do_mais_recente.index.str[3:]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo           282.71
# Minas Gerais        120.47
# Paraná               80.32
# Rio Grande do Sul    78.93
# Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
#Desafio: explorar mais métodos de String do python e str do pandas

# %%
populacao.index = populacao.index.str.strip()
populacao.head()
# Out:
#                 populacao
# uf
# São Paulo        46649132
# Minas Gerais     21411923
# Rio de Janeiro   17463349
# Bahia Bahia      14985284
# Paraná           11597484

# %%
populacao.index[0].strip()
# Out:
# 'São Paulo'

# %%
for estado in gastos_do_mais_recente.index:
  #print(f"{estado} {estado}")
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)
populacao.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Goiás', 'Maranhão', 'Amazonas', 'Espírito Santo', 'Paraíba',
#        'Mato Grosso', 'Rio Grande do Norte', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
gastos_e_populacao_recente = populacao.join(gastos_do_mais_recente)
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul
# uf
# São Paulo        46649132    282.71
# Minas Gerais     21411923    120.47
# Rio de Janeiro   17463349     71.54
# Bahia            14985284     58.90
# Paraná           11597484     80.32

# %% [markdown]
# #### Desafio 04 - Desenvolver uma função para a limpeza e tratamento dos dados, retornando duas tabelas "população" e "unida".

# %%
def limpar_unir_dfs(dados1, dados2):
  dados1 = dados1.dropna().copy()
  dados1["populacao"] = dados1["População "].str.replace(" ", "").astype(int)
  dados1["uf"] = dados1["Unidade federativa "]
  dados1 = dados1[["populacao", "uf"]].set_index("uf")
  dados1.index = dados1.index.str.strip()

  for estado in dados2.index:
    dados1.index = dados1.index.str.replace(f"{estado} {estado}", estado)

  return dados1.join(dados2)

# %%
dados_da_populacao_io = StringIO(dados_da_populacao)
populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
gastos_e_populacao_recente = limpar_unir_dfs(populacao, gastos_do_mais_recente)

# %%
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul
# uf
# São Paulo        46649132    282.71
# Minas Gerais     21411923    120.47
# Rio de Janeiro   17463349     71.54
# Bahia            14985284     58.90
# Paraná           11597484     80.32

# %% [markdown]
# ##Aula 2

# %%
def insere_gastos_e_gasto_por_habitante_para(todos_os_gastos, dados, mes:str):
  gastos_do_mes = todos_os_gastos[mes]
  dados[f"gastos_{mes}"] = gastos_do_mes * 1000000
  dados[f"gasto_por_habitante_{mes}"] = dados[f"gastos_{mes}"] / dados["populacao"]

# %%
ordenado_por_total.head()
# Out:
#                       2008/Fev  2008/Mar  ...  2020/Jul  2020/Ago
# Unidade da Federação                      ...
# 35 São Paulo            172.83    170.48  ...    282.71    140.41
# 31 Minas Gerais          70.30     79.12  ...    120.47     57.47
# 41 Paraná                48.86     55.61  ...     80.32     41.54
# 43 Rio Grande do Sul     45.90     52.93  ...     78.93     28.35
# 33 Rio de Janeiro        44.12     42.89  ...     71.54     36.26
#
# [5 rows x 151 columns]

# %%
ordenado_por_total.index = ordenado_por_total.index.str[3:]
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Jul")
gastos_e_populacao_recente[["gastos_2020/Jul", "populacao"]].plot()

# %%
gastos_e_populacao_recente["gasto_por_habitante"] = gastos_e_populacao_recente["gastos_2020/Jul"] / gastos_e_populacao_recente["populacao"]
gastos_e_populacao_recente.head()
# Out:
#                 populacao  ...  gasto_por_habitante
# uf                         ...
# São Paulo        46649132  ...                 6.06
# Minas Gerais     21411923  ...                 5.63
# Rio de Janeiro   17463349  ...                 4.10
# Bahia            14985284  ...                 3.93
# Paraná           11597484  ...                 6.93
#
# [5 rows x 5 columns]

# %%
gastos_e_populacao_recente["gasto_por_habitante"].plot(kind = "bar")

# %% [markdown]
# Conclusão: A hipótese de que os estados que possuem mais gastos absolutos poderiam ter mais gastos por habitante não se confirmou. Vemos uma dispersão grande, tendo estados que gastam mais no valor absoluto, não gastando tanto por habitante e vice versa.
# O que podemos inferir é que seria necessário uma análise mais detalhada como faixa etária ou quantidade de hospitais e leitos disponíveis por estado, para conseguirmos encontrar uma relação que explique esses valores.

# %%
gastos_e_populacao_recente["gasto_por_habitante"].sort_values(ascending = False).plot(kind='bar')

# %%
gastos_e_populacao_recente_pop = gastos_e_populacao_recente.sort_values(by = ['gastos_2020/Jul'], ascending = False)
gastos_e_populacao_recente_pop['gasto_por_habitante'].plot(kind = 'bar')

# %%
import seaborn as sns

sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x='populacao', y='gastos_2020/Jul')

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x='populacao', y='gastos_2020/Jul')

# %% [markdown]
# Conclusão: Conseguimos ver uma tendência no gráfico, uma reta média que pode ser traçada até o ponto mais alto, o que nos mostra que estados com populações maiores, tendem a gastar mais, porém isso não é uma regra.

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=gastos_e_populacao_recente, x='populacao', y='gasto_por_habitante_2020/Jul')

# %% [markdown]
# Conclusão: A partir desse gráfico, não consigo chegar a nenhuma conclusão, os pontos estão muito dispersos e não possuem nenhum padrão que seja possível traçar uma reta média. Portanto, a partir desse gráfico, não conseguimos concluir nada.

# %% [markdown]
# Desafio: fazer os últimos gráficos com os dois no mesmo

# %%
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Jun")
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Mai")
gastos_e_populacao_recente.head()
# Out:
#                 populacao  ...  gasto_por_habitante_2020/Mai
# uf                         ...
# São Paulo        46649132  ...                          6.49
# Minas Gerais     21411923  ...                          6.39
# Rio de Janeiro   17463349  ...                          4.94
# Bahia            14985284  ...                          4.12
# Paraná           11597484  ...                          9.15
#
# [5 rows x 9 columns]

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x='populacao', y='gastos_2020/Jul')
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x='populacao', y='gastos_2020/Jun')
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x='populacao', y='gastos_2020/Mai')

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=gastos_e_populacao_recente, x='populacao', y='gasto_por_habitante_2020/Jul')
sns.scatterplot(data=gastos_e_populacao_recente, x='populacao', y='gasto_por_habitante_2020/Jun')
sns.scatterplot(data=gastos_e_populacao_recente, x='populacao', y='gasto_por_habitante_2020/Mai')

# %% [markdown]
# ##Aula 3

# %%
ordenado_por_total.head()
# Out:
#                       2008/Fev  2008/Mar  ...  2020/Jul  2020/Ago
# Unidade da Federação                      ...
# São Paulo               172.83    170.48  ...    282.71    140.41
# Minas Gerais             70.30     79.12  ...    120.47     57.47
# Paraná                   48.86     55.61  ...     80.32     41.54
# Rio Grande do Sul        45.90     52.93  ...     78.93     28.35
# Rio de Janeiro           44.12     42.89  ...     71.54     36.26
#
# [5 rows x 151 columns]

# %%
sns.scatterplot( x = ordenado_por_total.columns, y = ordenado_por_total.loc["São Paulo"])

# %%
mensal = ordenado_por_total.T
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008/Fev                 172.83         70.30   48.86  ...  1.74     0.77   1.28
# 2008/Mar                 170.48         79.12   55.61  ...  2.06     0.88   1.18
# 2008/Abr                 170.28         79.05   56.12  ...  2.06     0.90   1.40
# 2008/Mai                 172.40         79.27   55.57  ...  2.23     1.03   1.41
# 2008/Jun                 175.42         79.61   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %%
sns.scatterplot(data = mensal, x = mensal.index, y = "São Paulo")

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y = "São Paulo")
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 350)
ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.title("Gastos Hospitalares Mensais do SUS no Estado de São Paulo", fontsize = 20)
plt.ylabel("Valor Gasto (em milhões de reais", fontsize = 12)
plt.xlabel("Meses", fontsize = 12)
plt.show()

# %% [markdown]
# ##Aula 4

# %%
from datetime import date

#documentação do datetime: https://docs.python.org/3/library/datetime.html

meses = {
    "Jan" : 1,
    "Fev" : 2,
    "Mar" : 3,
    "Abr" : 4,
    "Mai" : 5,
    "Jun" : 6,
    "Jul" : 7,
    "Ago" : 8,
    "Set" : 9,
    "Out" : 10,
    "Nov" : 11,
    "Dez" : 12
}

def para_dia(ano_mes):
  ano: int = int(ano_mes[:4])
  mes: str = ano_mes[5:]
  mes_numero: int = meses[mes]
  return date(ano, mes_numero, 1)

mensal.index = mensal.index.map(para_dia)
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008-02-01               172.83         70.30   48.86  ...  1.74     0.77   1.28
# 2008-03-01               170.48         79.12   55.61  ...  2.06     0.88   1.18
# 2008-04-01               170.28         79.05   56.12  ...  2.06     0.90   1.40
# 2008-05-01               172.40         79.27   55.57  ...  2.23     1.03   1.41
# 2008-06-01               175.42         79.61   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y = "São Paulo")
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 350)
#ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.title("Gastos Hospitalares Mensais do SUS no Estado de São Paulo", fontsize = 20)
plt.ylabel("Valor Gasto (em milhões de reais", fontsize = 12)
plt.xlabel("Meses", fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y = "São Paulo")
ax = sns.lineplot(data = mensal, x = mensal.index, y = "Minas Gerais")
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 350)
#ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.show()

# %%
mensal_aberto = mensal.reset_index().melt(id_vars=["index"], value_vars= mensal.columns)
mensal_aberto.columns = ["dia_mes_ano", "uf", "gasto"]
mensal_aberto["dia_mes_ano"] = mensal_aberto["dia_mes_ano"].astype('datetime64')
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto
# 0  2008-02-01  São Paulo 172.83
# 1  2008-03-01  São Paulo 170.48
# 2  2008-04-01  São Paulo 170.28
# 3  2008-05-01  São Paulo 172.40
# 4  2008-06-01  São Paulo 175.42

# %%
#como voltar atrás no melt - pivot
mensal_aberto.pivot(index='dia_mes_ano', columns='uf', values='gasto').head()
# Out:
# uf           Acre  Alagoas  Amapá  ...  Sergipe  São Paulo  Tocantins
# dia_mes_ano                        ...
# 2008-02-01   1.74     8.11   1.28  ...     4.64     172.83       5.05
# 2008-03-01   2.06     9.21   1.18  ...     5.02     170.48       5.20
# 2008-04-01   2.06    10.47   1.40  ...     5.27     170.28       5.34
# 2008-05-01   2.23     9.84   1.41  ...     5.37     172.40       5.34
# 2008-06-01   2.11    10.29   1.42  ...     4.98     175.42       5.40
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data = mensal_aberto, x = 'dia_mes_ano', y = "gasto", hue = "uf")
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 350)
#ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette

# %%
estados_escolhidos = mensal_aberto.uf.unique()[:5]
estados_escolhidos
# Out:
# array(['São Paulo', 'Minas Gerais', 'Paraná', 'Rio Grande do Sul',
#        'Rio de Janeiro'], dtype=object)

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data=mensal_aberto.query('uf in @estados_escolhidos'),
                  x="dia_mes_ano", y="gasto", hue="uf", palette='Set2')
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 350)
#ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.title("Gastos Hospitalares Mensais do SUS nos estados que mais gastaram", fontsize = 20)
plt.ylabel("Valor Gasto (em milhões de reais)", fontsize = 12)
plt.xlabel("Anos", fontsize = 12)
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ##Aula 5

# %%
mensal_aberto["mes"] = mensal_aberto["dia_mes_ano"].dt.month
mensal_aberto["ano"] = mensal_aberto["dia_mes_ano"].dt.year
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano
# 0  2008-02-01  São Paulo 172.83    2  2008
# 1  2008-03-01  São Paulo 170.48    3  2008
# 2  2008-04-01  São Paulo 170.28    4  2008
# 3  2008-05-01  São Paulo 172.40    5  2008
# 4  2008-06-01  São Paulo 175.42    6  2008

# %%
mensal_aberto.query("uf=='São Paulo'")
# Out:
#     dia_mes_ano         uf  gasto  mes   ano
# 0    2008-02-01  São Paulo 172.83    2  2008
# 1    2008-03-01  São Paulo 170.48    3  2008
# 2    2008-04-01  São Paulo 170.28    4  2008
# 3    2008-05-01  São Paulo 172.40    5  2008
# 4    2008-06-01  São Paulo 175.42    6  2008
# ..          ...        ...    ...  ...   ...
# 146  2020-04-01  São Paulo 251.70    4  2020
# 147  2020-05-01  São Paulo 302.86    5  2020
# 148  2020-06-01  São Paulo 299.06    6  2020
# 149  2020-07-01  São Paulo 282.71    7  2020
# 150  2020-08-01  São Paulo 140.41    8  2020
#
# [151 rows x 5 columns]

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data = mensal_aberto.query("uf=='São Paulo'"), x = 'mes', y = "gasto", hue = "ano")
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 350)
#ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.show()

# %%
dias_por_mes = {
    1 : 31,
    2 : 28,
    3 : 31,
    4 : 30,
    5 : 31,
    6 : 30,
    7 : 31,
    8 : 31,
    9 : 30,
    10 : 31,
    11 : 30,
    12 : 31
}

# %%
mensal_aberto['gasto_diario'] = mensal_aberto['gasto'] / mensal_aberto['mes'].map(dias_por_mes)
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  gasto_diario
# 0  2008-02-01  São Paulo 172.83    2  2008          6.17
# 1  2008-03-01  São Paulo 170.48    3  2008          5.50
# 2  2008-04-01  São Paulo 170.28    4  2008          5.68
# 3  2008-05-01  São Paulo 172.40    5  2008          5.56
# 4  2008-06-01  São Paulo 175.42    6  2008          5.85

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data = mensal_aberto.query("uf=='São Paulo'"), x = 'mes', y = "gasto_diario", hue = "ano")
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 12)
#ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.show()

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(data = mensal_aberto.query("uf=='Rio de Janeiro'"), x = 'mes', y = "gasto_diario", hue = "ano")
plt.xticks(rotation=30)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.ylim(0, 4)
#ax.xaxis.set_major_locator(ticker.IndexLocator(base = 12, offset = 11))
plt.grid(linestyle = "--", color = 'grey')
plt.show()

# %% [markdown]
# #### Desafio 01: Melhorar o gráfico ano a ano: - Mudar a palete de cor, colocar um título descritivo, adicionar ticks com o nome de cada mês no eixo x.

# %% [markdown]
# Solução 1

# %% [markdown]
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.strftime.html#pandas-series-dt-strftime

# %%
mensal_aberto.dia_mes_ano.dt.strftime("%b")
# Out:
# 0       Feb
# 1       Mar
# 2       Apr
# 3       May
# 4       Jun
#        ...
# 4072    Apr
# 4073    May
# 4074    Jun
# 4075    Jul
# 4076    Aug
# Name: dia_mes_ano, Length: 4077, dtype: object

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='São Paulo'"),
                  x=mensal_aberto.dia_mes_ano.dt.strftime("%b"),
                  y="gasto_diario", hue="ano",  palette='tab20b')
plt.xticks(rotation=30)
ax.set_title("Gastos no periodo Estado de São Paulo")
ax.set_xlabel("Meses")
ax.set_ylabel("Gastos em milhões")
plt.legend(bbox_to_anchor=(1, 1))
plt.ylim(0, 12)
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# Solução 2

# %% [markdown]
# https://matplotlib.org/3.3.3/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %%
labels = ['Jan', 'Fev', 'Mar', 'Abr',
          'Mai', 'Jun', 'Jul', 'Ago',
          'Set', 'Out', 'Nov', 'Dez']
x = np.arange(1,len(labels)+1)

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='São Paulo'"), x="mes",
                  y="gasto_diario", hue="ano",  palette='tab20b')
plt.xticks(rotation=30)
ax.set_title("Gastos no periodo Estado de São Paulo")
ax.set_xlabel("Meses")
ax.set_ylabel("Gastos em milhões")
plt.legend(bbox_to_anchor=(1, 1))
plt.ylim(0, 12)
plt.grid(linestyle="--")

ax.set_xticks(x)
ax.set_xticklabels(labels)

plt.show()

# %% [markdown]
# #### Desafio 02: Pegar estados de climas diferentes (por exemplo, norte e sul) e plotar o gráfico de linhas, comparar ambos e compartilhar suas análises.

# %%
mensal_aberto.uf.unique()
# Out:
# array(['São Paulo', 'Minas Gerais', 'Paraná', 'Rio Grande do Sul',
#        'Rio de Janeiro', 'Bahia', 'Pernambuco', 'Santa Catarina', 'Ceará',
#        'Goiás', 'Pará', 'Maranhão', 'Espírito Santo',
#        'Rio Grande do Norte', 'Paraíba', 'Distrito Federal',
#        'Mato Grosso do Sul', 'Piauí', 'Alagoas', 'Mato Grosso',
#        'Amazonas', 'Sergipe', 'Tocantins', 'Rondônia', 'Acre', 'Roraima',
#        'Amapá'], dtype=object)

# %%
plt.figure(figsize=(16,6))
plt.subplot(121)
ax = sns.lineplot(data=mensal_aberto.query("uf == 'Paraná'"), x="mes",
                  y="gasto_diario", hue="ano",  palette='tab20b')
plt.xticks(rotation=30)
ax.set_title("Gastos no periodo Estado Paraná")
ax.set_xlabel("Meses")
ax.set_ylabel("Gastos em milhões")
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4)
plt.ylim(0, 6)
plt.grid(linestyle="--")

ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.subplot(122)
ax = sns.lineplot(data=mensal_aberto.query("uf == 'Pará'"), x="mes",
                  y="gasto_diario", hue="ano",  palette='tab20b')
plt.xticks(rotation=30)
ax.set_title("Gastos no periodo Estado Pará")
ax.set_xlabel("Meses")
ax.set_ylabel("Gastos em milhões")
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4)
plt.ylim(0, 6)
plt.grid(linestyle="--")

ax.set_xticks(x)
ax.set_xticklabels(labels)

plt.show()

# %% [markdown]
# ##Aula 6

# %%
estado_a_analisar = mensal_aberto.query("uf=='São Paulo'")
estado_a_analisar.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  gasto_diario
# 0  2008-02-01  São Paulo 172.83    2  2008          6.17
# 1  2008-03-01  São Paulo 170.48    3  2008          5.50
# 2  2008-04-01  São Paulo 170.28    4  2008          5.68
# 3  2008-05-01  São Paulo 172.40    5  2008          5.56
# 4  2008-06-01  São Paulo 175.42    6  2008          5.85

# %%
gastos_por_ano = estado_a_analisar.groupby("ano").sum()
gastos_por_ano.head()
# Out:
#        gasto  mes  gasto_diario
# ano
# 2008 1960.23   77         64.60
# 2009 2489.03   78         81.82
# 2010 2696.62   78         88.63
# 2011 2794.55   78         91.91
# 2012 2873.97   78         94.47

# %%
gastos_por_ano.plot(kind = 'pie', y = 'gasto')

# %%
sns.scatterplot(data=gastos_por_ano, x = gastos_por_ano.index, y = "gasto")

# %%
sns.lineplot(data=gastos_por_ano, x = gastos_por_ano.index, y = "gasto")

# %%
sns.barplot(data=gastos_por_ano, x = gastos_por_ano.index, y = "gasto", palette=sns.color_palette("rocket_r", 13))

# %% [markdown]
# palete de cores do seaborn: http://seaborn.pydata.org/tutorial/color_palettes.html

# %%
estados = ["São Paulo", "Minas Gerais", "Pernambuco"]
por_ano_dos_estados = mensal_aberto.query("uf in @estados").groupby(["uf", "ano"]).sum().reset_index()
por_ano_dos_estados.head()
# Out:
#              uf   ano   gasto  mes  gasto_diario
# 0  Minas Gerais  2008  894.35   77         29.44
# 1  Minas Gerais  2009 1149.14   78         37.77
# 2  Minas Gerais  2010 1217.49   78         40.03
# 3  Minas Gerais  2011 1315.02   78         43.24
# 4  Minas Gerais  2012 1408.35   78         46.29

# %%
sns.lineplot(data=por_ano_dos_estados, x = "ano", y = "gasto", hue = "uf")

# %%
sns.catplot(data=por_ano_dos_estados, x = "ano", y = "gasto", kind = "bar", col = "uf")

# %% [markdown]
# Documentação catplot: https://seaborn.pydata.org/generated/seaborn.catplot.html

# %%
sns.catplot(data=por_ano_dos_estados, x = "ano", y = "gasto", kind = "bar", row = "uf")

# %% [markdown]
# Desafio: explorar a documentação (API) do seaborn, do matplotlib.

# %% [markdown]
# Desafio: pensar, elaborar novos gráficos

# %% [markdown]
# Desafio: baixe uma outra base do tabnet e execute sua análise lá

# %% [markdown]
# #### Desafio 01: Reordenar as cores pelo valor do eixo y.

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.rank.html?highlight=rank#pandas.Series.rank

# %%
gastos_ordenados = gastos_por_ano['gasto'].rank(method='max').astype(int)
gastos_ordenados
# Out:
# ano
# 2008     1
# 2009     3
# 2010     4
# 2011     5
# 2012     6
# 2013     7
# 2014     9
# 2015     8
# 2016    10
# 2017    11
# 2018    12
# 2019    13
# 2020     2
# Name: gasto, dtype: int64

# %%
index_ordenados = gastos_ordenados -1
colors = sns.color_palette("rocket_r", 13)
palette = [colors[x] for x in index_ordenados]

# %%
ax = sns.barplot(data=gastos_por_ano, x=gastos_por_ano.index, y="gasto", palette=palette)
plt.xticks(rotation = 45)
plt.show()
